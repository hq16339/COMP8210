# %%
#load data
import json
import re
file_name = 'raw_data.json'

with open(file_name, 'r', encoding='utf-8', errors='ignore') as f:
    a_str = f.read()
    valid_json =re.sub(r"\/\*.*\*\/", ',',a_str)
    valid_json =re.sub(r"\n\n", '',valid_json)
    valid_json =re.sub(r"ObjectId", '',valid_json)
    valid_json =re.sub(r"\(", '',valid_json)
    valid_json =re.sub(r"\)", '',valid_json)
    valid_json =re.sub(r"\\\"", '',valid_json)
    valid_json =re.sub(r"\\\"", '',valid_json)+"\]"
    data = json.loads(valid_json)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[33], line 15
#      13 valid_json =re.sub(r"\\\"", '',valid_json)
#      14 valid_json =re.sub(r"\\\"", '',valid_json)+"\]"
# ---> 15 data = json.loads(valid_json)
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 291 column 24 (char 9657)

# %%
valid_jsonp[:100000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 valid_jsonp[:100000]
#
# NameError: name 'valid_jsonp' is not defined

# %%
a='''{
    "_id" : "abe415aa5e7133a4a61c0d8317875",
    "id" : "149715690143449899009",
    "objectType" : "activity",
    "actor" : {
        "objectType" : "person",
        "id" : "10243188921458",
        "link" : "http://www.twitter.com/losebabyweight1",
        "displayName" : "losebabyweight",
        "postedTime" : "2010-09-09T22:40:10.000Z",
        "image" : "https://pbs.twimg.com/profile_images/522696965503455233/WfF2aJ7N_normal.png",
        "summary" : "http://www.losebabyweight.com.au offers mums safe and proven plans to lose weight. Lose an average of 1kg a week.",
        "links" : [ 
            {
                "href" : "http://www.losebabyweight.com.au",
                "rel" : "me"
            }
        ],
        "friendsCount" : 218,
        "followersCount" : 1960,
        "listedCount" : 17,
        "statusesCount" : 14439,
        "twitterTimeZone" : "Sydney",
        "verified" : false,
        "utcOffset" : "39600",
        "preferredUsername" : "losebabyweight1",
        "languages" : [ 
            "en"
        ],
        "location" : {
            "objectType" : "place",
            "displayName" : "Australia"
        },
        "favoritesCount" : 0
    },
    "verb" : "post",
    "postedTime" : "2016-04-01T00:00:01.000Z",
    "generator" : {
        "displayName" : "Facebook",
        "link" : "http://www.facebook.com/twitter"
    },
    "provider" : {
        "objectType" : "service",
        "displayName" : "Twitter",
        "link" : "http://www.twitter.com"
    },
    "link" : "http://twitter.com/losebabyweight1/statuses/715690143449899009",
    "text" : "CONGRATULATIONS Suzie Walker on both your beautiful little man and your FANTASTIC commitment and hard work. You... https://t.co/m4QLVq0BTr",
    "object" : {
        "objectType" : "note",
        "id" : "1345715690143449899009",
        "summary" : "CONGRATULATIONS Suzie Walker on both your beautiful little man and your FANTASTIC commitment and hard work. You... https://t.co/m4QLVq0BTr",
        "link" : "http://twitter.com/losebabyweight1/statuses/715690143449899009",
        "postedTime" : "2016-04-01T00:00:01.000Z"
    },
    "favoritesCount" : 0,
    "twitter_entities" : {
        "hashtags" : [],
        "urls" : [ 
            {
                "url" : "https://t.co/m4QLVq0BTr",
                "expanded_url" : "http://fb.me/WUTD9TnQ",
                "display_url" : "fb.me/WUTD9TnQ",
                "indices" : [ 
                    115, 
                    138
                ]
            }
        ],
        "user_mentions" : [],
        "symbols" : []
    },
    "twitter_filter_level" : "low",
    "twitter_lang" : "en",
    "retweetCount" : 0,
    "gnip" : {
        "matching_rules" : [ 
            {
                "value" : "bio_location: Australia",
                "tag" : null
            }
        ],
        "urls" : [ 
            {
                "url" : "https://t.co/m4QLVq0BTr",
                "expanded_url" : "https://www.facebook.com/photo.php?fbid=1257229527624685",
                "expanded_status" : 403
            }
        ],
        "klout_score" : 44,
        "language" : {
            "value" : "en"
        },
        "profileLocations" : [ 
            {
                "objectType" : "place",
                "geo" : {
                    "type" : "point",
                    "coordinates" : [ 
                        135.0, 
                        -25.0
                    ]
                },
                "address" : {
                    "country" : "Australia",
                    "countryCode" : "AU"
                },
                "displayName" : "Australia"
            }
        ]
    }
}

{
    "_id" : "abe415aa5e7133a4a61c0d8317876",
    "id" : "149715690141306650624",
    "objectType" : "activity",
    "actor" : {
        "objectType" : "person",
        "id" : "1024397578801",
        "link" : "http://www.twitter.com/wantirnaweather",
        "displayName" : "Wantirna Weather",
        "postedTime" : "2009-12-18T02:34:57.000Z",
        "image" : "https://pbs.twimg.com/profile_images/580069194/Eclipse_003vsm_normal.jpg",
        "summary" : "Personal Weather Station from Wantirna, Victoria, Australia.",
        "links" : [ 
            {
                "href" : "http://www.vic-weather.info",
                "rel" : "me"
            }
        ],
        "friendsCount" : 28,
        "followersCount" : 80,
        "listedCount" : 12,
        "statusesCount" : 66248,
        "twitterTimeZone" : "Melbourne",
        "verified" : false,
        "utcOffset" : "39600",
        "preferredUsername" : "wantirnaweather",
        "languages" : [ 
            "en"
        ],
        "location" : {
            "objectType" : "place",
            "displayName" : "Victoria, Australia"
        },
        "favoritesCount" : 1
    },
    "verb" : "post",
    "postedTime" : "2016-04-01T00:00:01.000Z",
    "generator" : {
        "displayName" : "Weather Display Tweet",
        "link" : "http://www.weather-display.com"
    },
    "provider" : {
        "objectType" : "service",
        "displayName" : "Twitter",
        "link" : "http://www.twitter.com"
    },
    "link" : "http://twitter.com/wantirnaweather/statuses/715690141306650624",
    "text" : "Wantirna, VIC, AU 11:00 AM Temp 19.8°C, RH 67pct, Winds NNW @ 0.0 km/h, Rain Today  0 mm, 1014.3 hpa &amp; Steady. #vicweather",
    "object" : {
        "objectType" : "note",
        "id" : "1345715690141306650624",
        "summary" : "Wantirna, VIC, AU 11:00 AM Temp 19.8°C, RH 67pct, Winds NNW @ 0.0 km/h, Rain Today  0 mm, 1014.3 hpa &amp; Steady. #vicweather",
        "link" : "http://twitter.com/wantirnaweather/statuses/715690141306650624",
        "postedTime" : "2016-04-01T00:00:01.000Z"
    },
    "favoritesCount" : 0,
    "twitter_entities" : {
        "hashtags" : [ 
            {
                "text" : "vicweather",
                "indices" : [ 
                    115, 
                    126
                ]
            }
        ],
        "urls" : [],
        "user_mentions" : [],
        "symbols" : []
    },
    "twitter_filter_level" : "low",
    "twitter_lang" : "en",
    "retweetCount" : 0,
    "gnip" : {
        "matching_rules" : [ 
            {
                "value" : "bio_location: Australia",
                "tag" : null
            }
        ],
        "klout_score" : 28,
        "language" : {
            "value" : "en"
        },
        "profileLocations" : [ 
            {
                "objectType" : "place",
                "geo" : {
                    "type" : "point",
                    "coordinates" : [ 
                        145.0, 
                        -37.0
                    ]
                },
                "address" : {
                    "country" : "Australia",
                    "countryCode" : "AU",
                    "region" : "Victoria"
                },
                "displayName" : "Victoria, Australia"
            }
        ]
    }
}
'''
json.loads(a)
import demjson
data = demjson.decode(a, encoding='utf-8')
print(data)
print("返回值类型：", type(data))
print(data['_id'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[28], line 219
#       1 a='''{
#       2     "_id" : "abe415aa5e7133a4a61c0d8317875",
#       3     "id" : "149715690143449899009",
#    (...)
#     217 }
#     218 '''
# --> 219 json.loads(a)
#     220 import demjson
#     221 data = demjson.decode(a, encoding='utf-8')
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/anaconda3/lib/python3.11/json/decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 114 column 1 (char 3689)
